# %% [markdown]
# # problem 0
#
# This is the 0th problem from the site [https://projecteuler.net/register]
#
# i'm going to work this out here in order to begin registration

# %%
def oddSquareNumbers(n):
    l = np.arange(1,n+1,2)
    return(l**2)

np.sum(oddSquareNumbers(679000))
# Out:
# 52174473166553500

# %%
osn = oddSquareNumbers(679000)
# print(osn)

# %%
np.sum(osn)
# Out:
# 52174473166553500

# %%
for i in np.arange(1,10,2):
    print(i, i**2)
# Out:
# 1 1
# 3 9
# 5 25
# 7 49
# 9 81
