# %% [markdown]
# # reading stock market data
#
# first the data

# %%
df = pd.read_html('https://www.multpl.com/inflation-adjusted-s-p-500/table/by-month')

# %%
df = df[0]

# %%
df
# Out:
#               Date    Value
# 0     Nov 13, 2025  6771.58
# 1      Nov 1, 2025  6811.76
# 2      Oct 1, 2025  6735.69
# 3      Sep 1, 2025  6584.02
# 4      Aug 1, 2025  6425.25
# ...            ...      ...
# 1855   May 1, 1871   128.65
# 1856   Apr 1, 1871   122.58
# 1857   Mar 1, 1871   114.91
# 1858   Feb 1, 1871   113.83
# 1859   Jan 1, 1871   115.74
#
# [1860 rows x 2 columns]

# %%
fig0, ax0 = plt.subplots()
ax0.plot(df['Date'][::-1], df['Value'][::-1]) # slices are since the data is listed backwards in time
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df['Date'][::-1]
# Out:
# 1859     Jan 1, 1871
# 1858     Feb 1, 1871
# 1857     Mar 1, 1871
# 1856     Apr 1, 1871
# 1855     May 1, 1871
#             ...
# 4        Aug 1, 2025
# 3        Sep 1, 2025
# 2        Oct 1, 2025
# 1        Nov 1, 2025
# 0       Nov 13, 2025
# Name: Date, Length: 1860, dtype: object
