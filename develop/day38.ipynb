# %% [markdown]
# # day 38 | 251201 M
#
# Today we began looking at Fourier Transforms and we started with the definition of a Fourier series:
#
# $$f(x) = \sum_{k=0}^{\infty} \alpha_k \cos $$

# %%
from IPython.display import display
display('251125-day38.pdf')
# Out:
# '251125-day38.pdf'
