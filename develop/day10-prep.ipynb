# %% [markdown]
# # day 10 prep
#
# integration
#
# 1. rectangle rule
# 2. trapezoid rule
# 3. think through the differences in how you code this up
#
# integrating $\sin(x)$ from 0 to $\pi$.
#
# this should be $-\cos(x)|_0^{\pi} = -cos(\pi)+cos(0) = 2$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
-np.cos(np.pi) + np.cos(0)
# Out:
# 2.0

# %%
x = np.linspace(0, 5, 10)
y = x**2 + x + 1

# %%
# need a dx
dx = x[1]-x[0]

# %%
ydx = y * dx

# %%
y
# Out:
# array([ 1.        ,  1.86419753,  3.34567901,  5.44444444,  8.16049383,
#        11.49382716, 15.44444444, 20.01234568, 25.19753086, 31.        ])

# %%
ydx
# Out:
# array([ 0.55555556,  1.03566529,  1.85871056,  3.02469136,  4.53360768,
#         6.38545953,  8.58024691, 11.11796982, 13.99862826, 17.22222222])

# %%
ydx.sum()
# Out:
# 68.3127572016461

# %% [markdown]
# so that is not too bad when the answer was 2... but we can do better. we need to look at how exacly we were doing this sum.

# %%
fig, ax = plt.subplots()

ax.plot(x, y, 'o--')
ax.bar(x, y, alpha=0.5, align='edge', width = dx)
# Out:
# <BarContainer object of 10 artists>
